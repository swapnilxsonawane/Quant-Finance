# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import enum 
from mpl_toolkits import mplot3d
from scipy.interpolate import RegularGridInterpolator

# %%
class OptionType(enum.Enum):
    CALL = 1.0
    PUT = -1.0

def GeneratePathsGBM(NoOfPaths,NoOfSteps,T,r,sigma,S_0):    
    Z = np.random.normal(0.0,1.0,[NoOfPaths,NoOfSteps])
    X = np.zeros([NoOfPaths, NoOfSteps+1])
    W = np.zeros([NoOfPaths, NoOfSteps+1])
    time = np.zeros([NoOfSteps+1])
        
    X[:,0] = np.log(S_0)
    
    dt = T / float(NoOfSteps)
    for i in range(0,NoOfSteps):

    # Making sure that samples from the normal distribution have mean 0 and variance 1

        if NoOfPaths > 1:
            Z[:,i] = (Z[:,i] - np.mean(Z[:,i])) / np.std(Z[:,i])
        W[:,i+1] = W[:,i] + np.power(dt, 0.5)*Z[:,i]
        X[:,i+1] = X[:,i] + (r - 0.5 * sigma * sigma) * dt + sigma * (W[:,i+1]-W[:,i])
        time[i+1] = time[i] +dt
        
    # Compute exponent of ABM

    S = np.exp(X)
    paths = {"time":time,"S":S}
    return paths

# Black-Scholes call option price

def BS_Call_Put_Option_Price(CP,S_0,K,sigma,t,T,r):
    K = np.array(K).reshape([len(K),1])
    d1    = (np.log(S_0 / K) + (r + 0.5 * np.power(sigma,2.0)) 
    * (T-t)) / (sigma * np.sqrt(T-t))
    d2    = d1 - sigma * np.sqrt(T-t)
    if CP == OptionType.CALL:
        value = st.norm.cdf(d1) * S_0 - st.norm.cdf(d2) * K * np.exp(-r * (T-t))
    elif CP == OptionType.PUT:
        value = st.norm.cdf(-d2) * K * np.exp(-r * (T-t)) - st.norm.cdf(-d1)*S_0
    return value

def BS_Delta(CP,S_0,K,sigma,t,T,r):
    # When defining a time grid it may happen that the last grid point 
    # lies slightly a bit behind the maturity time

    if t-T>10e-20 and T-t<10e-7:
        t=T
    K = np.array(K).reshape([len(K),1])
    d1    = (np.log(S_0 / K) + (r + 0.5 * np.power(sigma,2.0)) * \
             (T-t)) / (sigma * np.sqrt(T-t))
    if CP == OptionType.CALL:
        value = st.norm.cdf(d1)
    elif CP == OptionType.PUT:
       value = st.norm.cdf(d1)-1.0
    return value


def mainCalculation():
    NoOfPaths = 1000
    NoOfSteps = 200
    T         = 1.0
    r         = 0.1
    sigma     = 0.2
    s0        = 1.0
    K         = [0.95]
    CP        = OptionType.CALL
    
    np.random.seed(1)
    Paths = GeneratePathsGBM(NoOfPaths,NoOfSteps,T,r,sigma,s0)
    time  = Paths["time"]
    S     = Paths["S"]
    
    # Setting up some handy lambda values

    C = lambda t,K,S0: BS_Call_Put_Option_Price(CP,S0,K,sigma,t,T,r)
    Delta = lambda t,K,S0: BS_Delta(CP,S0,K,sigma,t,T,r)
    
    # Setting up the initial portfolio

    PnL = np.zeros([NoOfPaths,NoOfSteps+1])
    delta_init= Delta(0.0,K,s0)
    PnL[:,0] = C(0.0,K,s0) - delta_init * s0
            
    CallM      = np.zeros([NoOfPaths,NoOfSteps+1])
    CallM[:,0] = C(0.0,K,s0)
    DeltaM     = np.zeros([NoOfPaths,NoOfSteps+1])
    DeltaM[:,0] = Delta(0,K,s0)
    
    for i in range(1,NoOfSteps+1):
        dt = time[i] - time[i-1]
        delta_old  = Delta(time[i-1],K,S[:,i-1])
        delta_curr = Delta(time[i],K,S[:,i])
        
        PnL[:,i]    =  PnL[:,i-1]*np.exp(r*dt) - (delta_curr-delta_old)*S[:,i] # PnL
        CallM[:,i]  = C(time[i],K,S[:,i])
        DeltaM[:,i] = delta_curr
    
    # Final transaction, payment of the option (if in the money) and selling the hedge

    PnL[:,-1] = PnL[:,-1] -np.maximum(S[:,-1]-K,0) +  DeltaM[:,-1]*S[:,-1]
    
    # We plot only one path at the time

    path_id = 13
    plt.figure(1)
    plt.plot(time,S[path_id,:])
    plt.plot(time,CallM[path_id,:])
    plt.plot(time,DeltaM[path_id,:])
    plt.plot(time,PnL[path_id,:])
    plt.legend(['Stock','CallPrice','Delta','PnL'])
    plt.grid()
    
    # Plot the histogram of the PnL

    plt.figure(2)
    plt.hist(PnL[:,-1],50)
    plt.grid()
    plt.xlim([-0.1,0.1])
    plt.title('histogram of P&L')
    
    # Analysis for each path

    for i in range(0,NoOfPaths):
        print('path_id = {0:2d}, PnL(t_0)={1:0.4f}, PnL(Tm-1) ={2:0.4f},S(t_m) = {3:0.4f}, max(S(tm)-K,0)= {4:0.4f}, PnL(t_m) = {5:0.4f}'.format(i,PnL[0,0],
              PnL[i,-2],S[i,-1],np.max(S[i,-1]-K,0),PnL[i,-1]))

# %%
mainCalculation()
# Out:
# <ipython-input-2-4cf245057293>:50: RuntimeWarning: divide by zero encountered in true_divide
#   d1    = (np.log(S_0 / K) + (r + 0.5 * np.power(sigma,2.0)) * \
# <ipython-input-2-4cf245057293>:35: RuntimeWarning: invalid value encountered in sqrt
#   * (T-t)) / (sigma * np.sqrt(T-t))
# <ipython-input-2-4cf245057293>:36: RuntimeWarning: invalid value encountered in sqrt
#   d2    = d1 - sigma * np.sqrt(T-t)
# path_id =  0, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9462,S(t_m) = 1.4569, max(S(tm)-K,0)= 0.5069, PnL(t_m) = 0.0033
# path_id =  1, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9513,S(t_m) = 1.0439, max(S(tm)-K,0)= 0.0939, PnL(t_m) = -0.0018
# path_id =  2, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9505,S(t_m) = 1.3998, max(S(tm)-K,0)= 0.4498, PnL(t_m) = -0.0010
# path_id =  3, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0015,S(t_m) = 0.8577, max(S(tm)-K,0)= -0.0923, PnL(t_m) = -0.0015
# path_id =  4, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9480,S(t_m) = 1.3177, max(S(tm)-K,0)= 0.3677, PnL(t_m) = 0.0015
# path_id =  5, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8128,S(t_m) = 0.9499, max(S(tm)-K,0)= -0.0001, PnL(t_m) = 0.0040
# path_id =  6, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.6110, max(S(tm)-K,0)= 0.6610, PnL(t_m) = 0.0005
# path_id =  7, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9510,S(t_m) = 1.1789, max(S(tm)-K,0)= 0.2289, PnL(t_m) = -0.0014
# path_id =  8, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9574,S(t_m) = 1.1829, max(S(tm)-K,0)= 0.2329, PnL(t_m) = -0.0079
# path_id =  9, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5252,S(t_m) = 0.9707, max(S(tm)-K,0)= 0.0207, PnL(t_m) = 0.0028
# path_id = 10, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9444,S(t_m) = 1.0012, max(S(tm)-K,0)= 0.0512, PnL(t_m) = 0.0051
# path_id = 11, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8067,S(t_m) = 0.9732, max(S(tm)-K,0)= 0.0232, PnL(t_m) = -0.0110
# path_id = 12, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9478,S(t_m) = 1.0198, max(S(tm)-K,0)= 0.0698, PnL(t_m) = 0.0017
# path_id = 13, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9484,S(t_m) = 1.1377, max(S(tm)-K,0)= 0.1877, PnL(t_m) = 0.0011
# path_id = 14, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0860,S(t_m) = 0.9163, max(S(tm)-K,0)= -0.0337, PnL(t_m) = 0.0107
# path_id = 15, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.9246, max(S(tm)-K,0)= 0.9746, PnL(t_m) = 0.0001
# path_id = 16, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0062,S(t_m) = 0.8714, max(S(tm)-K,0)= -0.0786, PnL(t_m) = -0.0062
# path_id = 17, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0019,S(t_m) = 0.6557, max(S(tm)-K,0)= -0.2943, PnL(t_m) = -0.0019
# path_id = 18, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9466,S(t_m) = 1.1035, max(S(tm)-K,0)= 0.1535, PnL(t_m) = 0.0029
# path_id = 19, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9548,S(t_m) = 1.1885, max(S(tm)-K,0)= 0.2385, PnL(t_m) = -0.0053
# path_id = 20, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.3114, max(S(tm)-K,0)= 0.3614, PnL(t_m) = -0.0001
# path_id = 21, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.0427, max(S(tm)-K,0)= 0.0927, PnL(t_m) = -0.0001
# path_id = 22, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 1.5090, max(S(tm)-K,0)= 0.5590, PnL(t_m) = -0.0016
# path_id = 23, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.5117, max(S(tm)-K,0)= 0.5617, PnL(t_m) = 0.0013
# path_id = 24, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.2999, max(S(tm)-K,0)= 0.3499, PnL(t_m) = 0.0009
# path_id = 25, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9449,S(t_m) = 1.0050, max(S(tm)-K,0)= 0.0550, PnL(t_m) = 0.0003
# path_id = 26, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.0415, max(S(tm)-K,0)= 0.0915, PnL(t_m) = -0.0003
# path_id = 27, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9528,S(t_m) = 1.1321, max(S(tm)-K,0)= 0.1821, PnL(t_m) = -0.0032
# path_id = 28, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0083,S(t_m) = 0.9035, max(S(tm)-K,0)= -0.0465, PnL(t_m) = 0.0117
# path_id = 29, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0009,S(t_m) = 0.6410, max(S(tm)-K,0)= -0.3090, PnL(t_m) = -0.0009
# path_id = 30, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.2507,S(t_m) = 0.9353, max(S(tm)-K,0)= -0.0147, PnL(t_m) = 0.0042
# path_id = 31, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.3110, max(S(tm)-K,0)= 0.3610, PnL(t_m) = 0.0007
# path_id = 32, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9493,S(t_m) = 1.0362, max(S(tm)-K,0)= 0.0862, PnL(t_m) = 0.0002
# path_id = 33, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.0541, max(S(tm)-K,0)= 0.1041, PnL(t_m) = 0.0014
# path_id = 34, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0023,S(t_m) = 0.8374, max(S(tm)-K,0)= -0.1126, PnL(t_m) = 0.0023
# path_id = 35, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0004,S(t_m) = 0.8677, max(S(tm)-K,0)= -0.0823, PnL(t_m) = -0.0004
# path_id = 36, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0274,S(t_m) = 0.9044, max(S(tm)-K,0)= -0.0456, PnL(t_m) = -0.0179
# path_id = 37, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9476,S(t_m) = 1.0970, max(S(tm)-K,0)= 0.1470, PnL(t_m) = 0.0019
# path_id = 38, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9463,S(t_m) = 1.0855, max(S(tm)-K,0)= 0.1355, PnL(t_m) = 0.0032
# path_id = 39, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9476,S(t_m) = 1.3477, max(S(tm)-K,0)= 0.3977, PnL(t_m) = 0.0019
# path_id = 40, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9519,S(t_m) = 1.2594, max(S(tm)-K,0)= 0.3094, PnL(t_m) = -0.0024
# path_id = 41, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0199,S(t_m) = 0.9210, max(S(tm)-K,0)= -0.0290, PnL(t_m) = 0.0012
# path_id = 42, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9550,S(t_m) = 1.0659, max(S(tm)-K,0)= 0.1159, PnL(t_m) = -0.0055
# path_id = 43, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9515,S(t_m) = 1.5955, max(S(tm)-K,0)= 0.6455, PnL(t_m) = -0.0020
# path_id = 44, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9069,S(t_m) = 0.9784, max(S(tm)-K,0)= 0.0284, PnL(t_m) = 0.0028
# path_id = 45, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9487,S(t_m) = 1.4023, max(S(tm)-K,0)= 0.4523, PnL(t_m) = 0.0008
# path_id = 46, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 1.2486, max(S(tm)-K,0)= 0.2986, PnL(t_m) = 0.0000
# path_id = 47, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9464,S(t_m) = 1.2172, max(S(tm)-K,0)= 0.2672, PnL(t_m) = 0.0031
# path_id = 48, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0022,S(t_m) = 0.9107, max(S(tm)-K,0)= -0.0393, PnL(t_m) = 0.0031
# path_id = 49, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.0512, max(S(tm)-K,0)= 0.1012, PnL(t_m) = 0.0006
# path_id = 50, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9447,S(t_m) = 1.3955, max(S(tm)-K,0)= 0.4455, PnL(t_m) = 0.0049
# path_id = 51, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.0964, max(S(tm)-K,0)= 0.1464, PnL(t_m) = 0.0012
# path_id = 52, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.0582, max(S(tm)-K,0)= 0.1082, PnL(t_m) = -0.0026
# path_id = 53, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1444,S(t_m) = 0.9462, max(S(tm)-K,0)= -0.0038, PnL(t_m) = -0.0042
# path_id = 54, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9484,S(t_m) = 1.2346, max(S(tm)-K,0)= 0.2846, PnL(t_m) = 0.0011
# path_id = 55, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9525,S(t_m) = 1.3927, max(S(tm)-K,0)= 0.4427, PnL(t_m) = -0.0029
# path_id = 56, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0016,S(t_m) = 0.8996, max(S(tm)-K,0)= -0.0504, PnL(t_m) = 0.0032
# path_id = 57, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9479,S(t_m) = 1.3982, max(S(tm)-K,0)= 0.4482, PnL(t_m) = 0.0017
# path_id = 58, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0077,S(t_m) = 0.8495, max(S(tm)-K,0)= -0.1005, PnL(t_m) = -0.0077
# path_id = 59, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.3097, max(S(tm)-K,0)= 0.3597, PnL(t_m) = 0.0006
# path_id = 60, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 1.3421, max(S(tm)-K,0)= 0.3921, PnL(t_m) = -0.0016
# path_id = 61, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9454,S(t_m) = 1.1068, max(S(tm)-K,0)= 0.1568, PnL(t_m) = 0.0041
# path_id = 62, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9523,S(t_m) = 1.4876, max(S(tm)-K,0)= 0.5376, PnL(t_m) = -0.0027
# path_id = 63, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9433,S(t_m) = 0.9813, max(S(tm)-K,0)= 0.0313, PnL(t_m) = 0.0048
# path_id = 64, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0010,S(t_m) = 0.6097, max(S(tm)-K,0)= -0.3403, PnL(t_m) = -0.0010
# path_id = 65, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0050,S(t_m) = 0.7485, max(S(tm)-K,0)= -0.2015, PnL(t_m) = -0.0050
# path_id = 66, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9459,S(t_m) = 1.0254, max(S(tm)-K,0)= 0.0754, PnL(t_m) = 0.0037
# path_id = 67, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.3661, max(S(tm)-K,0)= 0.4161, PnL(t_m) = 0.0014
# path_id = 68, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.1013, max(S(tm)-K,0)= 0.1513, PnL(t_m) = -0.0001
# path_id = 69, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0041,S(t_m) = 0.8587, max(S(tm)-K,0)= -0.0913, PnL(t_m) = -0.0041
# path_id = 70, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9476,S(t_m) = 1.2108, max(S(tm)-K,0)= 0.2608, PnL(t_m) = 0.0019
# path_id = 71, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0076,S(t_m) = 0.8086, max(S(tm)-K,0)= -0.1414, PnL(t_m) = -0.0076
# path_id = 72, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9470,S(t_m) = 1.1394, max(S(tm)-K,0)= 0.1894, PnL(t_m) = 0.0025
# path_id = 73, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 1.3681, max(S(tm)-K,0)= 0.4181, PnL(t_m) = 0.0036
# path_id = 74, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.5646, max(S(tm)-K,0)= 0.6146, PnL(t_m) = -0.0008
# path_id = 75, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.7282, max(S(tm)-K,0)= 0.7782, PnL(t_m) = -0.0007
# path_id = 76, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8069,S(t_m) = 0.9774, max(S(tm)-K,0)= 0.0274, PnL(t_m) = 0.0053
# path_id = 77, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.3965, max(S(tm)-K,0)= 0.4465, PnL(t_m) = -0.0027
# path_id = 78, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0006,S(t_m) = 0.7717, max(S(tm)-K,0)= -0.1783, PnL(t_m) = -0.0006
# path_id = 79, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0017,S(t_m) = 0.8899, max(S(tm)-K,0)= -0.0601, PnL(t_m) = 0.0017
# path_id = 80, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9491,S(t_m) = 1.1563, max(S(tm)-K,0)= 0.2063, PnL(t_m) = 0.0004
# path_id = 81, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9438,S(t_m) = 1.1502, max(S(tm)-K,0)= 0.2002, PnL(t_m) = 0.0057
# path_id = 82, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9525,S(t_m) = 1.1017, max(S(tm)-K,0)= 0.1517, PnL(t_m) = -0.0029
# path_id = 83, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.2151, max(S(tm)-K,0)= 0.2651, PnL(t_m) = 0.0001
# path_id = 84, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 1.0408, max(S(tm)-K,0)= 0.0908, PnL(t_m) = -0.0000
# path_id = 85, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4571,S(t_m) = 0.9369, max(S(tm)-K,0)= -0.0131, PnL(t_m) = 0.0001
# path_id = 86, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9487,S(t_m) = 1.6121, max(S(tm)-K,0)= 0.6621, PnL(t_m) = 0.0008
# path_id = 87, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9538,S(t_m) = 1.2658, max(S(tm)-K,0)= 0.3158, PnL(t_m) = -0.0043
# path_id = 88, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.2231,S(t_m) = 0.9752, max(S(tm)-K,0)= 0.0252, PnL(t_m) = -0.0121
# path_id = 89, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0020,S(t_m) = 0.8932, max(S(tm)-K,0)= -0.0568, PnL(t_m) = -0.0020
# path_id = 90, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0003,S(t_m) = 0.8656, max(S(tm)-K,0)= -0.0844, PnL(t_m) = -0.0003
# path_id = 91, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 1.0727, max(S(tm)-K,0)= 0.1227, PnL(t_m) = -0.0000
# path_id = 92, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8638,S(t_m) = 0.9635, max(S(tm)-K,0)= 0.0135, PnL(t_m) = -0.0007
# path_id = 93, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9509,S(t_m) = 1.4286, max(S(tm)-K,0)= 0.4786, PnL(t_m) = -0.0014
# path_id = 94, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0000,S(t_m) = 0.9042, max(S(tm)-K,0)= -0.0458, PnL(t_m) = 0.0009
# path_id = 95, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9468,S(t_m) = 1.3503, max(S(tm)-K,0)= 0.4003, PnL(t_m) = 0.0027
# path_id = 96, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.1105, max(S(tm)-K,0)= 0.1605, PnL(t_m) = 0.0008
# path_id = 97, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.2334, max(S(tm)-K,0)= 0.2834, PnL(t_m) = -0.0001
# path_id = 98, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0011,S(t_m) = 0.8041, max(S(tm)-K,0)= -0.1459, PnL(t_m) = -0.0011
# path_id = 99, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9501,S(t_m) = 1.1194, max(S(tm)-K,0)= 0.1694, PnL(t_m) = -0.0006
# path_id = 100, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9507,S(t_m) = 1.3163, max(S(tm)-K,0)= 0.3663, PnL(t_m) = -0.0012
# path_id = 101, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0021,S(t_m) = 0.7725, max(S(tm)-K,0)= -0.1775, PnL(t_m) = -0.0021
# path_id = 102, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0098,S(t_m) = 0.8890, max(S(tm)-K,0)= -0.0610, PnL(t_m) = 0.0098
# path_id = 103, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0008,S(t_m) = 0.8361, max(S(tm)-K,0)= -0.1139, PnL(t_m) = -0.0008
# path_id = 104, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0035,S(t_m) = 0.7572, max(S(tm)-K,0)= -0.1928, PnL(t_m) = -0.0035
# path_id = 105, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1639,S(t_m) = 0.9311, max(S(tm)-K,0)= -0.0189, PnL(t_m) = -0.0010
# path_id = 106, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9560,S(t_m) = 1.2035, max(S(tm)-K,0)= 0.2535, PnL(t_m) = -0.0065
# path_id = 107, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.0665, max(S(tm)-K,0)= 0.1165, PnL(t_m) = -0.0007
# path_id = 108, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9466,S(t_m) = 1.1710, max(S(tm)-K,0)= 0.2210, PnL(t_m) = 0.0029
# path_id = 109, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9461,S(t_m) = 1.1476, max(S(tm)-K,0)= 0.1976, PnL(t_m) = 0.0034
# path_id = 110, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9501,S(t_m) = 1.1659, max(S(tm)-K,0)= 0.2159, PnL(t_m) = -0.0005
# path_id = 111, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0003,S(t_m) = 0.7850, max(S(tm)-K,0)= -0.1650, PnL(t_m) = 0.0003
# path_id = 112, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9504,S(t_m) = 1.4808, max(S(tm)-K,0)= 0.5308, PnL(t_m) = -0.0009
# path_id = 113, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9507,S(t_m) = 1.0165, max(S(tm)-K,0)= 0.0665, PnL(t_m) = -0.0012
# path_id = 114, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.1088, max(S(tm)-K,0)= 0.1588, PnL(t_m) = 0.0005
# path_id = 115, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9473,S(t_m) = 0.9875, max(S(tm)-K,0)= 0.0375, PnL(t_m) = 0.0013
# path_id = 116, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.0379, max(S(tm)-K,0)= 0.0879, PnL(t_m) = -0.0002
# path_id = 117, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0006,S(t_m) = 0.8382, max(S(tm)-K,0)= -0.1118, PnL(t_m) = 0.0006
# path_id = 118, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9472,S(t_m) = 1.1901, max(S(tm)-K,0)= 0.2401, PnL(t_m) = 0.0023
# path_id = 119, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.4401, max(S(tm)-K,0)= 0.4901, PnL(t_m) = 0.0006
# path_id = 120, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.6252, max(S(tm)-K,0)= 0.6752, PnL(t_m) = -0.0001
# path_id = 121, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9510,S(t_m) = 1.0398, max(S(tm)-K,0)= 0.0898, PnL(t_m) = -0.0015
# path_id = 122, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9456,S(t_m) = 1.0141, max(S(tm)-K,0)= 0.0641, PnL(t_m) = 0.0039
# path_id = 123, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0014,S(t_m) = 0.8949, max(S(tm)-K,0)= -0.0551, PnL(t_m) = -0.0014
# path_id = 124, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9521,S(t_m) = 1.0209, max(S(tm)-K,0)= 0.0709, PnL(t_m) = -0.0026
# path_id = 125, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.4095, max(S(tm)-K,0)= 0.4595, PnL(t_m) = -0.0007
# path_id = 126, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0054,S(t_m) = 0.8435, max(S(tm)-K,0)= -0.1065, PnL(t_m) = 0.0054
# path_id = 127, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.1271, max(S(tm)-K,0)= 0.1771, PnL(t_m) = 0.0009
# path_id = 128, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.4642, max(S(tm)-K,0)= 0.5142, PnL(t_m) = -0.0001
# path_id = 129, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5866,S(t_m) = 0.9605, max(S(tm)-K,0)= 0.0105, PnL(t_m) = 0.0060
# path_id = 130, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9518,S(t_m) = 1.2456, max(S(tm)-K,0)= 0.2956, PnL(t_m) = -0.0023
# path_id = 131, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9608,S(t_m) = 1.2222, max(S(tm)-K,0)= 0.2722, PnL(t_m) = -0.0113
# path_id = 132, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.0855, max(S(tm)-K,0)= 0.1355, PnL(t_m) = 0.0010
# path_id = 133, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0016,S(t_m) = 0.8257, max(S(tm)-K,0)= -0.1243, PnL(t_m) = -0.0016
# path_id = 134, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.3633,S(t_m) = 0.9428, max(S(tm)-K,0)= -0.0072, PnL(t_m) = 0.0123
# path_id = 135, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0015,S(t_m) = 0.8233, max(S(tm)-K,0)= -0.1267, PnL(t_m) = -0.0015
# path_id = 136, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.3618, max(S(tm)-K,0)= 0.4118, PnL(t_m) = 0.0007
# path_id = 137, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0039,S(t_m) = 0.8405, max(S(tm)-K,0)= -0.1095, PnL(t_m) = 0.0039
# path_id = 138, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9437,S(t_m) = 1.1030, max(S(tm)-K,0)= 0.1530, PnL(t_m) = 0.0059
# path_id = 139, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0017,S(t_m) = 0.8156, max(S(tm)-K,0)= -0.1344, PnL(t_m) = 0.0017
# path_id = 140, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9465,S(t_m) = 1.1429, max(S(tm)-K,0)= 0.1929, PnL(t_m) = 0.0031
# path_id = 141, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9468,S(t_m) = 1.1444, max(S(tm)-K,0)= 0.1944, PnL(t_m) = 0.0027
# path_id = 142, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8484,S(t_m) = 0.9420, max(S(tm)-K,0)= -0.0080, PnL(t_m) = -0.0069
# path_id = 143, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9322,S(t_m) = 0.9638, max(S(tm)-K,0)= 0.0138, PnL(t_m) = -0.0044
# path_id = 144, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0017,S(t_m) = 0.7964, max(S(tm)-K,0)= -0.1536, PnL(t_m) = -0.0017
# path_id = 145, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0042,S(t_m) = 0.8309, max(S(tm)-K,0)= -0.1191, PnL(t_m) = -0.0042
# path_id = 146, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.0647, max(S(tm)-K,0)= 0.1147, PnL(t_m) = -0.0011
# path_id = 147, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9491,S(t_m) = 1.0203, max(S(tm)-K,0)= 0.0703, PnL(t_m) = 0.0004
# path_id = 148, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0018,S(t_m) = 0.9248, max(S(tm)-K,0)= -0.0252, PnL(t_m) = 0.0034
# path_id = 149, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0010,S(t_m) = 0.7268, max(S(tm)-K,0)= -0.2232, PnL(t_m) = -0.0010
# path_id = 150, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9524,S(t_m) = 1.0918, max(S(tm)-K,0)= 0.1418, PnL(t_m) = -0.0029
# path_id = 151, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.1377, max(S(tm)-K,0)= 0.1877, PnL(t_m) = 0.0014
# path_id = 152, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 0.9800, max(S(tm)-K,0)= 0.0300, PnL(t_m) = 0.0001
# path_id = 153, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.4653, max(S(tm)-K,0)= 0.5153, PnL(t_m) = -0.0002
# path_id = 154, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.1808, max(S(tm)-K,0)= 0.2308, PnL(t_m) = -0.0006
# path_id = 155, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9485,S(t_m) = 1.1273, max(S(tm)-K,0)= 0.1773, PnL(t_m) = 0.0011
# path_id = 156, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9526,S(t_m) = 1.1606, max(S(tm)-K,0)= 0.2106, PnL(t_m) = -0.0031
# path_id = 157, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9374,S(t_m) = 1.0450, max(S(tm)-K,0)= 0.0950, PnL(t_m) = 0.0121
# path_id = 158, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.6094, max(S(tm)-K,0)= 0.6594, PnL(t_m) = -0.0017
# path_id = 159, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9106,S(t_m) = 0.9765, max(S(tm)-K,0)= 0.0265, PnL(t_m) = 0.0045
# path_id = 160, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8767,S(t_m) = 0.9697, max(S(tm)-K,0)= 0.0197, PnL(t_m) = -0.0090
# path_id = 161, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0006,S(t_m) = 0.8699, max(S(tm)-K,0)= -0.0801, PnL(t_m) = -0.0006
# path_id = 162, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4425,S(t_m) = 0.9707, max(S(tm)-K,0)= 0.0207, PnL(t_m) = -0.0143
# path_id = 163, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0116,S(t_m) = 0.8966, max(S(tm)-K,0)= -0.0534, PnL(t_m) = 0.0116
# path_id = 164, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.2687, max(S(tm)-K,0)= 0.3187, PnL(t_m) = -0.0008
# path_id = 165, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9480,S(t_m) = 1.6466, max(S(tm)-K,0)= 0.6966, PnL(t_m) = 0.0016
# path_id = 166, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0032,S(t_m) = 0.7638, max(S(tm)-K,0)= -0.1862, PnL(t_m) = -0.0032
# path_id = 167, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.2582, max(S(tm)-K,0)= 0.3082, PnL(t_m) = -0.0008
# path_id = 168, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9508,S(t_m) = 1.4740, max(S(tm)-K,0)= 0.5240, PnL(t_m) = -0.0013
# path_id = 169, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.0892, max(S(tm)-K,0)= 0.1392, PnL(t_m) = -0.0016
# path_id = 170, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9477,S(t_m) = 1.2427, max(S(tm)-K,0)= 0.2927, PnL(t_m) = 0.0018
# path_id = 171, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9471,S(t_m) = 1.1071, max(S(tm)-K,0)= 0.1571, PnL(t_m) = 0.0025
# path_id = 172, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9492,S(t_m) = 1.5657, max(S(tm)-K,0)= 0.6157, PnL(t_m) = 0.0003
# path_id = 173, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8862,S(t_m) = 0.9773, max(S(tm)-K,0)= 0.0273, PnL(t_m) = -0.0083
# path_id = 174, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.3102, max(S(tm)-K,0)= 0.3602, PnL(t_m) = 0.0013
# path_id = 175, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9505,S(t_m) = 1.2316, max(S(tm)-K,0)= 0.2816, PnL(t_m) = -0.0010
# path_id = 176, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.2489, max(S(tm)-K,0)= 0.2989, PnL(t_m) = -0.0004
# path_id = 177, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1824,S(t_m) = 0.9081, max(S(tm)-K,0)= -0.0419, PnL(t_m) = -0.0128
# path_id = 178, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9518,S(t_m) = 1.3359, max(S(tm)-K,0)= 0.3859, PnL(t_m) = -0.0023
# path_id = 179, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.0645, max(S(tm)-K,0)= 0.1145, PnL(t_m) = 0.0012
# path_id = 180, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.4359, max(S(tm)-K,0)= 0.4859, PnL(t_m) = -0.0005
# path_id = 181, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5813,S(t_m) = 0.9652, max(S(tm)-K,0)= 0.0152, PnL(t_m) = 0.0018
# path_id = 182, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0043,S(t_m) = 0.8823, max(S(tm)-K,0)= -0.0677, PnL(t_m) = -0.0043
# path_id = 183, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.9093, max(S(tm)-K,0)= 0.9593, PnL(t_m) = -0.0027
# path_id = 184, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0002,S(t_m) = 0.8648, max(S(tm)-K,0)= -0.0852, PnL(t_m) = 0.0002
# path_id = 185, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9487,S(t_m) = 1.4606, max(S(tm)-K,0)= 0.5106, PnL(t_m) = 0.0008
# path_id = 186, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9456,S(t_m) = 1.0801, max(S(tm)-K,0)= 0.1301, PnL(t_m) = 0.0040
# path_id = 187, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9484,S(t_m) = 1.1670, max(S(tm)-K,0)= 0.2170, PnL(t_m) = 0.0012
# path_id = 188, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.2610,S(t_m) = 0.9295, max(S(tm)-K,0)= -0.0205, PnL(t_m) = -0.0001
# path_id = 189, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9526,S(t_m) = 1.0165, max(S(tm)-K,0)= 0.0665, PnL(t_m) = -0.0031
# path_id = 190, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0059,S(t_m) = 0.7803, max(S(tm)-K,0)= -0.1697, PnL(t_m) = -0.0059
# path_id = 191, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.4803, max(S(tm)-K,0)= 0.5303, PnL(t_m) = -0.0011
# path_id = 192, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0025,S(t_m) = 0.8295, max(S(tm)-K,0)= -0.1205, PnL(t_m) = -0.0025
# path_id = 193, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9540,S(t_m) = 1.1757, max(S(tm)-K,0)= 0.2257, PnL(t_m) = -0.0045
# path_id = 194, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.2328, max(S(tm)-K,0)= 0.2828, PnL(t_m) = -0.0000
# path_id = 195, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9479,S(t_m) = 1.1229, max(S(tm)-K,0)= 0.1729, PnL(t_m) = 0.0016
# path_id = 196, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1058,S(t_m) = 0.9592, max(S(tm)-K,0)= 0.0092, PnL(t_m) = -0.0028
# path_id = 197, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8100,S(t_m) = 0.9389, max(S(tm)-K,0)= -0.0111, PnL(t_m) = -0.0049
# path_id = 198, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9475,S(t_m) = 1.1121, max(S(tm)-K,0)= 0.1621, PnL(t_m) = 0.0021
# path_id = 199, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0055,S(t_m) = 0.8066, max(S(tm)-K,0)= -0.1434, PnL(t_m) = -0.0055
# path_id = 200, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9515,S(t_m) = 1.1201, max(S(tm)-K,0)= 0.1701, PnL(t_m) = -0.0019
# path_id = 201, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.2828, max(S(tm)-K,0)= 0.3328, PnL(t_m) = -0.0001
# path_id = 202, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8180,S(t_m) = 0.9592, max(S(tm)-K,0)= 0.0092, PnL(t_m) = 0.0012
# path_id = 203, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9417,S(t_m) = 1.0778, max(S(tm)-K,0)= 0.1278, PnL(t_m) = 0.0078
# path_id = 204, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.2325, max(S(tm)-K,0)= 0.2825, PnL(t_m) = 0.0014
# path_id = 205, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9539,S(t_m) = 1.0373, max(S(tm)-K,0)= 0.0873, PnL(t_m) = -0.0044
# path_id = 206, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0029,S(t_m) = 0.8949, max(S(tm)-K,0)= -0.0551, PnL(t_m) = 0.0029
# path_id = 207, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5656,S(t_m) = 0.9385, max(S(tm)-K,0)= -0.0115, PnL(t_m) = 0.0054
# path_id = 208, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0002,S(t_m) = 0.7937, max(S(tm)-K,0)= -0.1563, PnL(t_m) = -0.0002
# path_id = 209, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0019,S(t_m) = 0.8839, max(S(tm)-K,0)= -0.0661, PnL(t_m) = -0.0019
# path_id = 210, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 1.1359, max(S(tm)-K,0)= 0.1859, PnL(t_m) = 0.0035
# path_id = 211, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9168,S(t_m) = 0.9779, max(S(tm)-K,0)= 0.0279, PnL(t_m) = 0.0020
# path_id = 212, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9516,S(t_m) = 1.7662, max(S(tm)-K,0)= 0.8162, PnL(t_m) = -0.0021
# path_id = 213, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9556,S(t_m) = 1.0859, max(S(tm)-K,0)= 0.1359, PnL(t_m) = -0.0061
# path_id = 214, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9505,S(t_m) = 1.9735, max(S(tm)-K,0)= 1.0235, PnL(t_m) = -0.0009
# path_id = 215, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0024,S(t_m) = 0.6608, max(S(tm)-K,0)= -0.2892, PnL(t_m) = 0.0024
# path_id = 216, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8983,S(t_m) = 0.9980, max(S(tm)-K,0)= 0.0480, PnL(t_m) = 0.0046
# path_id = 217, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0068,S(t_m) = 0.9091, max(S(tm)-K,0)= -0.0409, PnL(t_m) = 0.0068
# path_id = 218, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9473,S(t_m) = 1.1726, max(S(tm)-K,0)= 0.2226, PnL(t_m) = 0.0023
# path_id = 219, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.8007, max(S(tm)-K,0)= 0.8507, PnL(t_m) = -0.0008
# path_id = 220, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9517,S(t_m) = 1.1500, max(S(tm)-K,0)= 0.2000, PnL(t_m) = -0.0022
# path_id = 221, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9459,S(t_m) = 1.0476, max(S(tm)-K,0)= 0.0976, PnL(t_m) = 0.0037
# path_id = 222, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.2062, max(S(tm)-K,0)= 0.2562, PnL(t_m) = -0.0004
# path_id = 223, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9516,S(t_m) = 1.2466, max(S(tm)-K,0)= 0.2966, PnL(t_m) = -0.0021
# path_id = 224, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0036,S(t_m) = 0.8463, max(S(tm)-K,0)= -0.1037, PnL(t_m) = 0.0036
# path_id = 225, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9523,S(t_m) = 1.1445, max(S(tm)-K,0)= 0.1945, PnL(t_m) = -0.0028
# path_id = 226, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9479,S(t_m) = 1.2087, max(S(tm)-K,0)= 0.2587, PnL(t_m) = 0.0016
# path_id = 227, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4495,S(t_m) = 0.9712, max(S(tm)-K,0)= 0.0212, PnL(t_m) = 0.0063
# path_id = 228, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0042,S(t_m) = 0.6729, max(S(tm)-K,0)= -0.2771, PnL(t_m) = -0.0042
# path_id = 229, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0054,S(t_m) = 0.9240, max(S(tm)-K,0)= -0.0260, PnL(t_m) = 0.0068
# path_id = 230, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0007,S(t_m) = 0.8141, max(S(tm)-K,0)= -0.1359, PnL(t_m) = -0.0007
# path_id = 231, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.1252, max(S(tm)-K,0)= 0.1752, PnL(t_m) = 0.0009
# path_id = 232, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9519,S(t_m) = 1.0517, max(S(tm)-K,0)= 0.1017, PnL(t_m) = -0.0024
# path_id = 233, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9474,S(t_m) = 1.3123, max(S(tm)-K,0)= 0.3623, PnL(t_m) = 0.0021
# path_id = 234, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0156,S(t_m) = 0.8284, max(S(tm)-K,0)= -0.1216, PnL(t_m) = -0.0156
# path_id = 235, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9493,S(t_m) = 1.2250, max(S(tm)-K,0)= 0.2750, PnL(t_m) = 0.0002
# path_id = 236, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.0605, max(S(tm)-K,0)= 0.1105, PnL(t_m) = 0.0005
# path_id = 237, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9047,S(t_m) = 0.9441, max(S(tm)-K,0)= -0.0059, PnL(t_m) = -0.0095
# path_id = 238, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.2210, max(S(tm)-K,0)= 0.2710, PnL(t_m) = -0.0008
# path_id = 239, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.2732, max(S(tm)-K,0)= 0.3232, PnL(t_m) = -0.0017
# path_id = 240, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.0612, max(S(tm)-K,0)= 0.1112, PnL(t_m) = 0.0006
# path_id = 241, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 0.9934, max(S(tm)-K,0)= 0.0434, PnL(t_m) = -0.0005
# path_id = 242, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.4901, max(S(tm)-K,0)= 0.5401, PnL(t_m) = -0.0002
# path_id = 243, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0031,S(t_m) = 0.6159, max(S(tm)-K,0)= -0.3341, PnL(t_m) = -0.0031
# path_id = 244, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0013,S(t_m) = 0.8561, max(S(tm)-K,0)= -0.0939, PnL(t_m) = 0.0013
# path_id = 245, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.0888, max(S(tm)-K,0)= 0.1388, PnL(t_m) = 0.0006
# path_id = 246, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.1889, max(S(tm)-K,0)= 0.2389, PnL(t_m) = 0.0013
# path_id = 247, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9465,S(t_m) = 1.0815, max(S(tm)-K,0)= 0.1315, PnL(t_m) = 0.0030
# path_id = 248, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.0002, max(S(tm)-K,0)= 0.0502, PnL(t_m) = 0.0012
# path_id = 249, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9475,S(t_m) = 1.2660, max(S(tm)-K,0)= 0.3160, PnL(t_m) = 0.0020
# path_id = 250, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.2506, max(S(tm)-K,0)= 0.3006, PnL(t_m) = -0.0003
# path_id = 251, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9438,S(t_m) = 1.0733, max(S(tm)-K,0)= 0.1233, PnL(t_m) = 0.0057
# path_id = 252, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0011,S(t_m) = 0.8247, max(S(tm)-K,0)= -0.1253, PnL(t_m) = 0.0011
# path_id = 253, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9458,S(t_m) = 1.2225, max(S(tm)-K,0)= 0.2725, PnL(t_m) = 0.0037
# path_id = 254, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.0045, max(S(tm)-K,0)= 0.0545, PnL(t_m) = -0.0027
# path_id = 255, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.0577, max(S(tm)-K,0)= 0.1077, PnL(t_m) = -0.0003
# path_id = 256, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0043,S(t_m) = 0.8534, max(S(tm)-K,0)= -0.0966, PnL(t_m) = -0.0043
# path_id = 257, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9501,S(t_m) = 1.7691, max(S(tm)-K,0)= 0.8191, PnL(t_m) = -0.0005
# path_id = 258, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.0646, max(S(tm)-K,0)= 0.1146, PnL(t_m) = -0.0005
# path_id = 259, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9515,S(t_m) = 1.3083, max(S(tm)-K,0)= 0.3583, PnL(t_m) = -0.0019
# path_id = 260, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9594,S(t_m) = 0.9863, max(S(tm)-K,0)= 0.0363, PnL(t_m) = -0.0100
# path_id = 261, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9521,S(t_m) = 1.1736, max(S(tm)-K,0)= 0.2236, PnL(t_m) = -0.0026
# path_id = 262, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9484,S(t_m) = 1.0075, max(S(tm)-K,0)= 0.0575, PnL(t_m) = 0.0011
# path_id = 263, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0021,S(t_m) = 0.7082, max(S(tm)-K,0)= -0.2418, PnL(t_m) = 0.0021
# path_id = 264, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0128,S(t_m) = 0.9283, max(S(tm)-K,0)= -0.0217, PnL(t_m) = -0.0066
# path_id = 265, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9468,S(t_m) = 1.2396, max(S(tm)-K,0)= 0.2896, PnL(t_m) = 0.0027
# path_id = 266, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0022,S(t_m) = 0.8016, max(S(tm)-K,0)= -0.1484, PnL(t_m) = 0.0022
# path_id = 267, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9479,S(t_m) = 1.3025, max(S(tm)-K,0)= 0.3525, PnL(t_m) = 0.0017
# path_id = 268, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9452,S(t_m) = 1.0690, max(S(tm)-K,0)= 0.1190, PnL(t_m) = 0.0043
# path_id = 269, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9545,S(t_m) = 1.2108, max(S(tm)-K,0)= 0.2608, PnL(t_m) = -0.0050
# path_id = 270, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 1.3588, max(S(tm)-K,0)= 0.4088, PnL(t_m) = -0.0016
# path_id = 271, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.5346, max(S(tm)-K,0)= 0.5846, PnL(t_m) = 0.0005
# path_id = 272, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0007,S(t_m) = 0.7538, max(S(tm)-K,0)= -0.1962, PnL(t_m) = 0.0007
# path_id = 273, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0213,S(t_m) = 0.9120, max(S(tm)-K,0)= -0.0380, PnL(t_m) = -0.0203
# path_id = 274, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9550,S(t_m) = 1.0739, max(S(tm)-K,0)= 0.1239, PnL(t_m) = -0.0055
# path_id = 275, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.1164, max(S(tm)-K,0)= 0.1664, PnL(t_m) = -0.0005
# path_id = 276, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 0.9695, max(S(tm)-K,0)= 0.0195, PnL(t_m) = -0.0001
# path_id = 277, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9532,S(t_m) = 1.2954, max(S(tm)-K,0)= 0.3454, PnL(t_m) = -0.0036
# path_id = 278, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.6159, max(S(tm)-K,0)= 0.6659, PnL(t_m) = 0.0013
# path_id = 279, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9566,S(t_m) = 1.1620, max(S(tm)-K,0)= 0.2120, PnL(t_m) = -0.0071
# path_id = 280, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.2486, max(S(tm)-K,0)= 0.2986, PnL(t_m) = -0.0003
# path_id = 281, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9505,S(t_m) = 1.1763, max(S(tm)-K,0)= 0.2263, PnL(t_m) = -0.0009
# path_id = 282, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9297,S(t_m) = 0.9532, max(S(tm)-K,0)= 0.0032, PnL(t_m) = 0.0033
# path_id = 283, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9507,S(t_m) = 1.0421, max(S(tm)-K,0)= 0.0921, PnL(t_m) = -0.0012
# path_id = 284, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.1659, max(S(tm)-K,0)= 0.2159, PnL(t_m) = 0.0001
# path_id = 285, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0019,S(t_m) = 0.8515, max(S(tm)-K,0)= -0.0985, PnL(t_m) = 0.0019
# path_id = 286, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0063,S(t_m) = 0.9252, max(S(tm)-K,0)= -0.0248, PnL(t_m) = -0.0014
# path_id = 287, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9516,S(t_m) = 1.0532, max(S(tm)-K,0)= 0.1032, PnL(t_m) = -0.0021
# path_id = 288, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9528,S(t_m) = 1.1566, max(S(tm)-K,0)= 0.2066, PnL(t_m) = -0.0033
# path_id = 289, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.5033, max(S(tm)-K,0)= 0.5533, PnL(t_m) = 0.0006
# path_id = 290, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9477,S(t_m) = 1.6601, max(S(tm)-K,0)= 0.7101, PnL(t_m) = 0.0018
# path_id = 291, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0030,S(t_m) = 0.8756, max(S(tm)-K,0)= -0.0744, PnL(t_m) = 0.0030
# path_id = 292, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9501,S(t_m) = 1.1058, max(S(tm)-K,0)= 0.1558, PnL(t_m) = -0.0006
# path_id = 293, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9450,S(t_m) = 1.0154, max(S(tm)-K,0)= 0.0654, PnL(t_m) = 0.0045
# path_id = 294, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0448,S(t_m) = 0.9219, max(S(tm)-K,0)= -0.0281, PnL(t_m) = -0.0077
# path_id = 295, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.7531,S(t_m) = 0.9643, max(S(tm)-K,0)= 0.0143, PnL(t_m) = -0.0003
# path_id = 296, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9509,S(t_m) = 1.2585, max(S(tm)-K,0)= 0.3085, PnL(t_m) = -0.0014
# path_id = 297, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9480,S(t_m) = 1.1149, max(S(tm)-K,0)= 0.1649, PnL(t_m) = 0.0015
# path_id = 298, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 0.9866, max(S(tm)-K,0)= 0.0366, PnL(t_m) = -0.0007
# path_id = 299, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.2098, max(S(tm)-K,0)= 0.2598, PnL(t_m) = -0.0005
# path_id = 300, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 1.0899, max(S(tm)-K,0)= 0.1399, PnL(t_m) = -0.0015
# path_id = 301, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0017,S(t_m) = 0.8768, max(S(tm)-K,0)= -0.0732, PnL(t_m) = 0.0017
# path_id = 302, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0058,S(t_m) = 0.9124, max(S(tm)-K,0)= -0.0376, PnL(t_m) = -0.0052
# path_id = 303, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9536,S(t_m) = 1.1312, max(S(tm)-K,0)= 0.1812, PnL(t_m) = -0.0040
# path_id = 304, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.0666, max(S(tm)-K,0)= 0.1166, PnL(t_m) = 0.0008
# path_id = 305, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0016,S(t_m) = 0.8901, max(S(tm)-K,0)= -0.0599, PnL(t_m) = 0.0016
# path_id = 306, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9477,S(t_m) = 1.3838, max(S(tm)-K,0)= 0.4338, PnL(t_m) = 0.0018
# path_id = 307, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9463,S(t_m) = 1.3675, max(S(tm)-K,0)= 0.4175, PnL(t_m) = 0.0032
# path_id = 308, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 1.0201, max(S(tm)-K,0)= 0.0701, PnL(t_m) = 0.0036
# path_id = 309, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.0661, max(S(tm)-K,0)= 0.1161, PnL(t_m) = -0.0004
# path_id = 310, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9519,S(t_m) = 1.1544, max(S(tm)-K,0)= 0.2044, PnL(t_m) = -0.0024
# path_id = 311, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0040,S(t_m) = 0.9054, max(S(tm)-K,0)= -0.0446, PnL(t_m) = 0.0028
# path_id = 312, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9322,S(t_m) = 0.9739, max(S(tm)-K,0)= 0.0239, PnL(t_m) = 0.0095
# path_id = 313, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.1445, max(S(tm)-K,0)= 0.1945, PnL(t_m) = -0.0003
# path_id = 314, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 1.3095, max(S(tm)-K,0)= 0.3595, PnL(t_m) = -0.0016
# path_id = 315, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9453,S(t_m) = 1.0997, max(S(tm)-K,0)= 0.1497, PnL(t_m) = 0.0042
# path_id = 316, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0039,S(t_m) = 0.6835, max(S(tm)-K,0)= -0.2665, PnL(t_m) = 0.0039
# path_id = 317, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.1629, max(S(tm)-K,0)= 0.2129, PnL(t_m) = 0.0014
# path_id = 318, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0007,S(t_m) = 0.6876, max(S(tm)-K,0)= -0.2624, PnL(t_m) = -0.0007
# path_id = 319, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0023,S(t_m) = 0.8072, max(S(tm)-K,0)= -0.1428, PnL(t_m) = 0.0023
# path_id = 320, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9456,S(t_m) = 1.0632, max(S(tm)-K,0)= 0.1132, PnL(t_m) = 0.0039
# path_id = 321, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0047,S(t_m) = 0.8897, max(S(tm)-K,0)= -0.0603, PnL(t_m) = -0.0047
# path_id = 322, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.2010, max(S(tm)-K,0)= 0.2510, PnL(t_m) = -0.0007
# path_id = 323, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9462,S(t_m) = 1.0733, max(S(tm)-K,0)= 0.1233, PnL(t_m) = 0.0033
# path_id = 324, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0021,S(t_m) = 0.7923, max(S(tm)-K,0)= -0.1577, PnL(t_m) = -0.0021
# path_id = 325, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0073,S(t_m) = 0.8993, max(S(tm)-K,0)= -0.0507, PnL(t_m) = -0.0073
# path_id = 326, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9536,S(t_m) = 1.1852, max(S(tm)-K,0)= 0.2352, PnL(t_m) = -0.0041
# path_id = 327, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9416,S(t_m) = 1.1109, max(S(tm)-K,0)= 0.1609, PnL(t_m) = 0.0079
# path_id = 328, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0230,S(t_m) = 0.9433, max(S(tm)-K,0)= -0.0067, PnL(t_m) = 0.0031
# path_id = 329, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.3317,S(t_m) = 0.9590, max(S(tm)-K,0)= 0.0090, PnL(t_m) = 0.0137
# path_id = 330, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9480,S(t_m) = 1.2006, max(S(tm)-K,0)= 0.2506, PnL(t_m) = 0.0015
# path_id = 331, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9428,S(t_m) = 1.0862, max(S(tm)-K,0)= 0.1362, PnL(t_m) = 0.0067
# path_id = 332, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4285,S(t_m) = 0.9485, max(S(tm)-K,0)= -0.0015, PnL(t_m) = 0.0087
# path_id = 333, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4864,S(t_m) = 0.9498, max(S(tm)-K,0)= -0.0002, PnL(t_m) = 0.0034
# path_id = 334, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.1505, max(S(tm)-K,0)= 0.2005, PnL(t_m) = -0.0003
# path_id = 335, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9516,S(t_m) = 1.0771, max(S(tm)-K,0)= 0.1271, PnL(t_m) = -0.0020
# path_id = 336, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0437,S(t_m) = 0.9261, max(S(tm)-K,0)= -0.0239, PnL(t_m) = -0.0035
# path_id = 337, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9529,S(t_m) = 1.2289, max(S(tm)-K,0)= 0.2789, PnL(t_m) = -0.0033
# path_id = 338, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9485,S(t_m) = 1.2152, max(S(tm)-K,0)= 0.2652, PnL(t_m) = 0.0010
# path_id = 339, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0012,S(t_m) = 0.8578, max(S(tm)-K,0)= -0.0922, PnL(t_m) = 0.0012
# path_id = 340, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0027,S(t_m) = 0.7813, max(S(tm)-K,0)= -0.1687, PnL(t_m) = -0.0027
# path_id = 341, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.0740, max(S(tm)-K,0)= 0.1240, PnL(t_m) = -0.0017
# path_id = 342, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9507,S(t_m) = 1.0774, max(S(tm)-K,0)= 0.1274, PnL(t_m) = -0.0011
# path_id = 343, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9525,S(t_m) = 1.1828, max(S(tm)-K,0)= 0.2328, PnL(t_m) = -0.0030
# path_id = 344, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0072,S(t_m) = 0.8798, max(S(tm)-K,0)= -0.0702, PnL(t_m) = -0.0073
# path_id = 345, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9535,S(t_m) = 1.2030, max(S(tm)-K,0)= 0.2530, PnL(t_m) = -0.0039
# path_id = 346, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.2199,S(t_m) = 0.9390, max(S(tm)-K,0)= -0.0110, PnL(t_m) = 0.0010
# path_id = 347, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.1888, max(S(tm)-K,0)= 0.2388, PnL(t_m) = 0.0001
# path_id = 348, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9109,S(t_m) = 0.9546, max(S(tm)-K,0)= 0.0046, PnL(t_m) = 0.0040
# path_id = 349, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9515,S(t_m) = 1.1184, max(S(tm)-K,0)= 0.1684, PnL(t_m) = -0.0019
# path_id = 350, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0046,S(t_m) = 0.8129, max(S(tm)-K,0)= -0.1371, PnL(t_m) = 0.0046
# path_id = 351, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.3581, max(S(tm)-K,0)= 0.4081, PnL(t_m) = -0.0007
# path_id = 352, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.1514, max(S(tm)-K,0)= 0.2014, PnL(t_m) = 0.0012
# path_id = 353, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9473,S(t_m) = 1.3180, max(S(tm)-K,0)= 0.3680, PnL(t_m) = 0.0022
# path_id = 354, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.4693, max(S(tm)-K,0)= 0.5193, PnL(t_m) = -0.0001
# path_id = 355, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0029,S(t_m) = 0.7963, max(S(tm)-K,0)= -0.1537, PnL(t_m) = 0.0029
# path_id = 356, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.1826, max(S(tm)-K,0)= 0.2326, PnL(t_m) = 0.0009
# path_id = 357, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.2207, max(S(tm)-K,0)= 0.2707, PnL(t_m) = 0.0014
# path_id = 358, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0225,S(t_m) = 0.9437, max(S(tm)-K,0)= -0.0063, PnL(t_m) = -0.0050
# path_id = 359, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9457,S(t_m) = 1.0366, max(S(tm)-K,0)= 0.0866, PnL(t_m) = 0.0038
# path_id = 360, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9447,S(t_m) = 1.1368, max(S(tm)-K,0)= 0.1868, PnL(t_m) = 0.0049
# path_id = 361, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.6522,S(t_m) = 0.9605, max(S(tm)-K,0)= 0.0105, PnL(t_m) = -0.0168
# path_id = 362, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9492,S(t_m) = 1.3802, max(S(tm)-K,0)= 0.4302, PnL(t_m) = 0.0004
# path_id = 363, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9466,S(t_m) = 1.1329, max(S(tm)-K,0)= 0.1829, PnL(t_m) = 0.0029
# path_id = 364, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9461,S(t_m) = 1.0675, max(S(tm)-K,0)= 0.1175, PnL(t_m) = 0.0035
# path_id = 365, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0029,S(t_m) = 0.6915, max(S(tm)-K,0)= -0.2585, PnL(t_m) = -0.0029
# path_id = 366, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9667,S(t_m) = 0.9950, max(S(tm)-K,0)= 0.0450, PnL(t_m) = -0.0172
# path_id = 367, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9465,S(t_m) = 1.1889, max(S(tm)-K,0)= 0.2389, PnL(t_m) = 0.0030
# path_id = 368, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9534,S(t_m) = 1.0623, max(S(tm)-K,0)= 0.1123, PnL(t_m) = -0.0039
# path_id = 369, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0016,S(t_m) = 0.7524, max(S(tm)-K,0)= -0.1976, PnL(t_m) = -0.0016
# path_id = 370, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9511,S(t_m) = 0.9977, max(S(tm)-K,0)= 0.0477, PnL(t_m) = -0.0016
# path_id = 371, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.3214, max(S(tm)-K,0)= 0.3714, PnL(t_m) = -0.0001
# path_id = 372, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.7139,S(t_m) = 0.9647, max(S(tm)-K,0)= 0.0147, PnL(t_m) = 0.0050
# path_id = 373, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.2663, max(S(tm)-K,0)= 0.3163, PnL(t_m) = -0.0002
# path_id = 374, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0104,S(t_m) = 0.7994, max(S(tm)-K,0)= -0.1506, PnL(t_m) = -0.0104
# path_id = 375, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9509,S(t_m) = 1.1381, max(S(tm)-K,0)= 0.1881, PnL(t_m) = -0.0013
# path_id = 376, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0007,S(t_m) = 0.8946, max(S(tm)-K,0)= -0.0554, PnL(t_m) = 0.0007
# path_id = 377, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.2703, max(S(tm)-K,0)= 0.3203, PnL(t_m) = -0.0003
# path_id = 378, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.2952, max(S(tm)-K,0)= 0.3452, PnL(t_m) = 0.0012
# path_id = 379, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.3615, max(S(tm)-K,0)= 0.4115, PnL(t_m) = -0.0005
# path_id = 380, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.5012, max(S(tm)-K,0)= 0.5512, PnL(t_m) = -0.0011
# path_id = 381, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9467,S(t_m) = 1.1517, max(S(tm)-K,0)= 0.2017, PnL(t_m) = 0.0028
# path_id = 382, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 1.1480, max(S(tm)-K,0)= 0.1980, PnL(t_m) = 0.0001
# path_id = 383, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 1.0546, max(S(tm)-K,0)= 0.1046, PnL(t_m) = 0.0001
# path_id = 384, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9466,S(t_m) = 0.9793, max(S(tm)-K,0)= 0.0293, PnL(t_m) = 0.0003
# path_id = 385, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.0980, max(S(tm)-K,0)= 0.1480, PnL(t_m) = 0.0007
# path_id = 386, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9501,S(t_m) = 1.2287, max(S(tm)-K,0)= 0.2787, PnL(t_m) = -0.0006
# path_id = 387, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0040,S(t_m) = 0.7707, max(S(tm)-K,0)= -0.1793, PnL(t_m) = -0.0040
# path_id = 388, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8613,S(t_m) = 0.9488, max(S(tm)-K,0)= -0.0012, PnL(t_m) = 0.0035
# path_id = 389, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.1314, max(S(tm)-K,0)= 0.1814, PnL(t_m) = -0.0011
# path_id = 390, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9496,S(t_m) = 1.2194, max(S(tm)-K,0)= 0.2694, PnL(t_m) = -0.0001
# path_id = 391, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.2467, max(S(tm)-K,0)= 0.2967, PnL(t_m) = -0.0007
# path_id = 392, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.7776,S(t_m) = 0.9362, max(S(tm)-K,0)= -0.0138, PnL(t_m) = 0.0042
# path_id = 393, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9509,S(t_m) = 1.0328, max(S(tm)-K,0)= 0.0828, PnL(t_m) = -0.0014
# path_id = 394, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 0.9987, max(S(tm)-K,0)= 0.0487, PnL(t_m) = 0.0035
# path_id = 395, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9513,S(t_m) = 1.1936, max(S(tm)-K,0)= 0.2436, PnL(t_m) = -0.0018
# path_id = 396, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.6905, max(S(tm)-K,0)= 0.7405, PnL(t_m) = -0.0004
# path_id = 397, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0110,S(t_m) = 0.8805, max(S(tm)-K,0)= -0.0695, PnL(t_m) = -0.0110
# path_id = 398, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0063,S(t_m) = 0.8320, max(S(tm)-K,0)= -0.1180, PnL(t_m) = -0.0063
# path_id = 399, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.1147, max(S(tm)-K,0)= 0.1647, PnL(t_m) = -0.0005
# path_id = 400, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0028,S(t_m) = 0.6782, max(S(tm)-K,0)= -0.2718, PnL(t_m) = -0.0028
# path_id = 401, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0011,S(t_m) = 0.7703, max(S(tm)-K,0)= -0.1797, PnL(t_m) = 0.0011
# path_id = 402, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9528,S(t_m) = 1.0429, max(S(tm)-K,0)= 0.0929, PnL(t_m) = -0.0033
# path_id = 403, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.2169, max(S(tm)-K,0)= 0.2669, PnL(t_m) = -0.0004
# path_id = 404, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0033,S(t_m) = 0.8377, max(S(tm)-K,0)= -0.1123, PnL(t_m) = 0.0033
# path_id = 405, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0284,S(t_m) = 0.9126, max(S(tm)-K,0)= -0.0374, PnL(t_m) = -0.0081
# path_id = 406, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.6438,S(t_m) = 0.9538, max(S(tm)-K,0)= 0.0038, PnL(t_m) = 0.0136
# path_id = 407, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0009,S(t_m) = 0.8375, max(S(tm)-K,0)= -0.1125, PnL(t_m) = -0.0009
# path_id = 408, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.2705, max(S(tm)-K,0)= 0.3205, PnL(t_m) = 0.0005
# path_id = 409, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9487,S(t_m) = 1.7532, max(S(tm)-K,0)= 0.8032, PnL(t_m) = 0.0008
# path_id = 410, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9395,S(t_m) = 0.9823, max(S(tm)-K,0)= 0.0323, PnL(t_m) = -0.0073
# path_id = 411, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9465,S(t_m) = 1.3726, max(S(tm)-K,0)= 0.4226, PnL(t_m) = 0.0030
# path_id = 412, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9469,S(t_m) = 1.4421, max(S(tm)-K,0)= 0.4921, PnL(t_m) = 0.0026
# path_id = 413, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9480,S(t_m) = 1.3168, max(S(tm)-K,0)= 0.3668, PnL(t_m) = 0.0016
# path_id = 414, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9519,S(t_m) = 1.1726, max(S(tm)-K,0)= 0.2226, PnL(t_m) = -0.0024
# path_id = 415, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0003,S(t_m) = 0.8821, max(S(tm)-K,0)= -0.0679, PnL(t_m) = -0.0003
# path_id = 416, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.4406, max(S(tm)-K,0)= 0.4906, PnL(t_m) = 0.0005
# path_id = 417, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9493,S(t_m) = 1.3200, max(S(tm)-K,0)= 0.3700, PnL(t_m) = 0.0002
# path_id = 418, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.1573, max(S(tm)-K,0)= 0.2073, PnL(t_m) = 0.0010
# path_id = 419, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9495,S(t_m) = 0.9923, max(S(tm)-K,0)= 0.0423, PnL(t_m) = 0.0000
# path_id = 420, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.2330, max(S(tm)-K,0)= 0.2830, PnL(t_m) = 0.0012
# path_id = 421, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.7797, max(S(tm)-K,0)= 0.8297, PnL(t_m) = -0.0002
# path_id = 422, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9545,S(t_m) = 1.0073, max(S(tm)-K,0)= 0.0573, PnL(t_m) = -0.0063
# path_id = 423, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9540,S(t_m) = 1.3545, max(S(tm)-K,0)= 0.4045, PnL(t_m) = -0.0045
# path_id = 424, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0043,S(t_m) = 0.8352, max(S(tm)-K,0)= -0.1148, PnL(t_m) = -0.0043
# path_id = 425, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9470,S(t_m) = 1.2318, max(S(tm)-K,0)= 0.2818, PnL(t_m) = 0.0025
# ...
# path_id = 857, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.3259, max(S(tm)-K,0)= 0.3759, PnL(t_m) = -0.0005
# path_id = 858, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9473,S(t_m) = 1.2093, max(S(tm)-K,0)= 0.2593, PnL(t_m) = 0.0022
# path_id = 859, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0207,S(t_m) = 0.9275, max(S(tm)-K,0)= -0.0225, PnL(t_m) = -0.0010
# path_id = 860, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9551,S(t_m) = 1.0940, max(S(tm)-K,0)= 0.1440, PnL(t_m) = -0.0056
# path_id = 861, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.4091, max(S(tm)-K,0)= 0.4591, PnL(t_m) = -0.0007
# path_id = 862, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1393,S(t_m) = 0.9714, max(S(tm)-K,0)= 0.0214, PnL(t_m) = -0.0148
# path_id = 863, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9509,S(t_m) = 1.4286, max(S(tm)-K,0)= 0.4786, PnL(t_m) = -0.0014
# path_id = 864, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0003,S(t_m) = 0.8500, max(S(tm)-K,0)= -0.1000, PnL(t_m) = -0.0003
# path_id = 865, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.0096, max(S(tm)-K,0)= 0.0596, PnL(t_m) = 0.0005
# path_id = 866, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0050,S(t_m) = 0.9369, max(S(tm)-K,0)= -0.0131, PnL(t_m) = 0.0128
# path_id = 867, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0044,S(t_m) = 0.7587, max(S(tm)-K,0)= -0.1913, PnL(t_m) = 0.0044
# path_id = 868, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.1025, max(S(tm)-K,0)= 0.1525, PnL(t_m) = 0.0013
# path_id = 869, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0039,S(t_m) = 0.7513, max(S(tm)-K,0)= -0.1987, PnL(t_m) = -0.0039
# path_id = 870, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9514,S(t_m) = 1.6012, max(S(tm)-K,0)= 0.6512, PnL(t_m) = -0.0019
# path_id = 871, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0010,S(t_m) = 0.7082, max(S(tm)-K,0)= -0.2418, PnL(t_m) = 0.0010
# path_id = 872, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0032,S(t_m) = 0.7557, max(S(tm)-K,0)= -0.1943, PnL(t_m) = -0.0032
# path_id = 873, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9517,S(t_m) = 1.4839, max(S(tm)-K,0)= 0.5339, PnL(t_m) = -0.0022
# path_id = 874, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9500,S(t_m) = 1.3431, max(S(tm)-K,0)= 0.3931, PnL(t_m) = -0.0004
# path_id = 875, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9516,S(t_m) = 1.3643, max(S(tm)-K,0)= 0.4143, PnL(t_m) = -0.0021
# path_id = 876, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 1.3328, max(S(tm)-K,0)= 0.3828, PnL(t_m) = 0.0035
# path_id = 877, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0042,S(t_m) = 0.8447, max(S(tm)-K,0)= -0.1053, PnL(t_m) = -0.0042
# path_id = 878, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.3643, max(S(tm)-K,0)= 0.4143, PnL(t_m) = -0.0017
# path_id = 879, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.1890, max(S(tm)-K,0)= 0.2390, PnL(t_m) = 0.0001
# path_id = 880, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9475,S(t_m) = 1.4274, max(S(tm)-K,0)= 0.4774, PnL(t_m) = 0.0021
# path_id = 881, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.3350,S(t_m) = 0.9599, max(S(tm)-K,0)= 0.0099, PnL(t_m) = 0.0046
# path_id = 882, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9468,S(t_m) = 1.5473, max(S(tm)-K,0)= 0.5973, PnL(t_m) = 0.0027
# path_id = 883, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.3550, max(S(tm)-K,0)= 0.4050, PnL(t_m) = 0.0006
# path_id = 884, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0015,S(t_m) = 0.8372, max(S(tm)-K,0)= -0.1128, PnL(t_m) = 0.0015
# path_id = 885, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9497,S(t_m) = 1.0302, max(S(tm)-K,0)= 0.0802, PnL(t_m) = -0.0002
# path_id = 886, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0013,S(t_m) = 0.6913, max(S(tm)-K,0)= -0.2587, PnL(t_m) = -0.0013
# path_id = 887, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9514,S(t_m) = 1.2993, max(S(tm)-K,0)= 0.3493, PnL(t_m) = -0.0019
# path_id = 888, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9471,S(t_m) = 1.5116, max(S(tm)-K,0)= 0.5616, PnL(t_m) = 0.0024
# path_id = 889, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0001,S(t_m) = 0.7628, max(S(tm)-K,0)= -0.1872, PnL(t_m) = -0.0001
# path_id = 890, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9546,S(t_m) = 1.0396, max(S(tm)-K,0)= 0.0896, PnL(t_m) = -0.0050
# path_id = 891, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9492,S(t_m) = 1.2799, max(S(tm)-K,0)= 0.3299, PnL(t_m) = 0.0003
# path_id = 892, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0027,S(t_m) = 0.9040, max(S(tm)-K,0)= -0.0460, PnL(t_m) = -0.0025
# path_id = 893, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.1795, max(S(tm)-K,0)= 0.2295, PnL(t_m) = -0.0008
# path_id = 894, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.3558, max(S(tm)-K,0)= 0.4058, PnL(t_m) = -0.0026
# path_id = 895, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9460,S(t_m) = 1.0825, max(S(tm)-K,0)= 0.1325, PnL(t_m) = 0.0035
# path_id = 896, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0018,S(t_m) = 0.8914, max(S(tm)-K,0)= -0.0586, PnL(t_m) = -0.0018
# path_id = 897, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.4009, max(S(tm)-K,0)= 0.4509, PnL(t_m) = -0.0004
# path_id = 898, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9514,S(t_m) = 1.4886, max(S(tm)-K,0)= 0.5386, PnL(t_m) = -0.0019
# path_id = 899, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9521,S(t_m) = 1.0945, max(S(tm)-K,0)= 0.1445, PnL(t_m) = -0.0026
# path_id = 900, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.3496, max(S(tm)-K,0)= 0.3996, PnL(t_m) = 0.0005
# path_id = 901, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.9196, max(S(tm)-K,0)= 0.9696, PnL(t_m) = 0.0009
# path_id = 902, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9514,S(t_m) = 1.3948, max(S(tm)-K,0)= 0.4448, PnL(t_m) = -0.0019
# path_id = 903, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0017,S(t_m) = 0.6733, max(S(tm)-K,0)= -0.2767, PnL(t_m) = -0.0017
# path_id = 904, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9526,S(t_m) = 1.2268, max(S(tm)-K,0)= 0.2768, PnL(t_m) = -0.0030
# path_id = 905, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9461,S(t_m) = 1.0925, max(S(tm)-K,0)= 0.1425, PnL(t_m) = 0.0034
# path_id = 906, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.3741, max(S(tm)-K,0)= 0.4241, PnL(t_m) = -0.0011
# path_id = 907, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9541,S(t_m) = 1.1984, max(S(tm)-K,0)= 0.2484, PnL(t_m) = -0.0046
# path_id = 908, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4216,S(t_m) = 0.9552, max(S(tm)-K,0)= 0.0052, PnL(t_m) = 0.0023
# path_id = 909, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9433,S(t_m) = 1.2717, max(S(tm)-K,0)= 0.3217, PnL(t_m) = 0.0063
# path_id = 910, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.4306, max(S(tm)-K,0)= 0.4806, PnL(t_m) = 0.0007
# path_id = 911, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9457,S(t_m) = 1.2746, max(S(tm)-K,0)= 0.3246, PnL(t_m) = 0.0038
# path_id = 912, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9498,S(t_m) = 1.2535, max(S(tm)-K,0)= 0.3035, PnL(t_m) = -0.0003
# path_id = 913, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9522,S(t_m) = 1.2432, max(S(tm)-K,0)= 0.2932, PnL(t_m) = -0.0026
# path_id = 914, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9488,S(t_m) = 1.0101, max(S(tm)-K,0)= 0.0601, PnL(t_m) = -0.0064
# path_id = 915, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9483,S(t_m) = 1.0225, max(S(tm)-K,0)= 0.0725, PnL(t_m) = 0.0012
# path_id = 916, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.3501, max(S(tm)-K,0)= 0.4001, PnL(t_m) = 0.0006
# path_id = 917, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0016,S(t_m) = 0.9082, max(S(tm)-K,0)= -0.0418, PnL(t_m) = 0.0028
# path_id = 918, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.6143, max(S(tm)-K,0)= 0.6643, PnL(t_m) = -0.0008
# path_id = 919, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9457,S(t_m) = 1.0341, max(S(tm)-K,0)= 0.0841, PnL(t_m) = 0.0038
# path_id = 920, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9467,S(t_m) = 1.0601, max(S(tm)-K,0)= 0.1101, PnL(t_m) = 0.0028
# path_id = 921, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9466,S(t_m) = 1.4116, max(S(tm)-K,0)= 0.4616, PnL(t_m) = 0.0029
# path_id = 922, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9527,S(t_m) = 1.3957, max(S(tm)-K,0)= 0.4457, PnL(t_m) = -0.0032
# path_id = 923, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9493,S(t_m) = 1.2615, max(S(tm)-K,0)= 0.3115, PnL(t_m) = 0.0003
# path_id = 924, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.0164, max(S(tm)-K,0)= 0.0664, PnL(t_m) = 0.0010
# path_id = 925, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8362,S(t_m) = 0.9859, max(S(tm)-K,0)= 0.0359, PnL(t_m) = 0.0017
# path_id = 926, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9494,S(t_m) = 1.2508, max(S(tm)-K,0)= 0.3008, PnL(t_m) = 0.0001
# path_id = 927, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9418,S(t_m) = 1.1640, max(S(tm)-K,0)= 0.2140, PnL(t_m) = 0.0077
# path_id = 928, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0022,S(t_m) = 0.7792, max(S(tm)-K,0)= -0.1708, PnL(t_m) = -0.0022
# path_id = 929, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.0698, max(S(tm)-K,0)= 0.1198, PnL(t_m) = 0.0006
# path_id = 930, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.3901, max(S(tm)-K,0)= 0.4401, PnL(t_m) = -0.0008
# path_id = 931, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9510,S(t_m) = 1.1477, max(S(tm)-K,0)= 0.1977, PnL(t_m) = -0.0014
# path_id = 932, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.2014, max(S(tm)-K,0)= 0.2514, PnL(t_m) = 0.0005
# path_id = 933, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0067,S(t_m) = 0.9011, max(S(tm)-K,0)= -0.0489, PnL(t_m) = 0.0068
# path_id = 934, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9479,S(t_m) = 1.1757, max(S(tm)-K,0)= 0.2257, PnL(t_m) = 0.0017
# path_id = 935, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.8289,S(t_m) = 0.9927, max(S(tm)-K,0)= 0.0427, PnL(t_m) = -0.0117
# path_id = 936, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0011,S(t_m) = 0.8494, max(S(tm)-K,0)= -0.1006, PnL(t_m) = -0.0011
# path_id = 937, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9521,S(t_m) = 1.5138, max(S(tm)-K,0)= 0.5638, PnL(t_m) = -0.0026
# path_id = 938, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0016,S(t_m) = 0.8212, max(S(tm)-K,0)= -0.1288, PnL(t_m) = -0.0016
# path_id = 939, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9188,S(t_m) = 0.9577, max(S(tm)-K,0)= 0.0077, PnL(t_m) = -0.0090
# path_id = 940, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9471,S(t_m) = 0.9900, max(S(tm)-K,0)= 0.0400, PnL(t_m) = 0.0022
# path_id = 941, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.4588,S(t_m) = 0.9660, max(S(tm)-K,0)= 0.0160, PnL(t_m) = 0.0063
# path_id = 942, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5951,S(t_m) = 0.9668, max(S(tm)-K,0)= 0.0168, PnL(t_m) = -0.0023
# path_id = 943, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9555,S(t_m) = 1.1350, max(S(tm)-K,0)= 0.1850, PnL(t_m) = -0.0060
# path_id = 944, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0028,S(t_m) = 0.8540, max(S(tm)-K,0)= -0.0960, PnL(t_m) = 0.0028
# path_id = 945, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9450,S(t_m) = 1.1048, max(S(tm)-K,0)= 0.1548, PnL(t_m) = 0.0045
# path_id = 946, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9541,S(t_m) = 1.0109, max(S(tm)-K,0)= 0.0609, PnL(t_m) = -0.0046
# path_id = 947, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0252,S(t_m) = 0.9151, max(S(tm)-K,0)= -0.0349, PnL(t_m) = 0.0061
# path_id = 948, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9463,S(t_m) = 1.2759, max(S(tm)-K,0)= 0.3259, PnL(t_m) = 0.0032
# path_id = 949, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9485,S(t_m) = 1.2954, max(S(tm)-K,0)= 0.3454, PnL(t_m) = 0.0010
# path_id = 950, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.1511, max(S(tm)-K,0)= 0.2011, PnL(t_m) = -0.0011
# path_id = 951, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9445,S(t_m) = 1.0114, max(S(tm)-K,0)= 0.0614, PnL(t_m) = 0.0050
# path_id = 952, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0006,S(t_m) = 0.8795, max(S(tm)-K,0)= -0.0705, PnL(t_m) = -0.0006
# path_id = 953, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9421,S(t_m) = 1.0415, max(S(tm)-K,0)= 0.0915, PnL(t_m) = 0.0074
# path_id = 954, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.1173, max(S(tm)-K,0)= 0.1673, PnL(t_m) = 0.0014
# path_id = 955, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.2794, max(S(tm)-K,0)= 0.3294, PnL(t_m) = -0.0010
# path_id = 956, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9441,S(t_m) = 1.0471, max(S(tm)-K,0)= 0.0971, PnL(t_m) = 0.0055
# path_id = 957, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0051,S(t_m) = 0.8780, max(S(tm)-K,0)= -0.0720, PnL(t_m) = 0.0051
# path_id = 958, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0037,S(t_m) = 0.8615, max(S(tm)-K,0)= -0.0885, PnL(t_m) = -0.0037
# path_id = 959, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9499,S(t_m) = 1.0814, max(S(tm)-K,0)= 0.1314, PnL(t_m) = -0.0003
# path_id = 960, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9512,S(t_m) = 1.0714, max(S(tm)-K,0)= 0.1214, PnL(t_m) = -0.0016
# path_id = 961, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9468,S(t_m) = 1.2164, max(S(tm)-K,0)= 0.2664, PnL(t_m) = 0.0027
# path_id = 962, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9470,S(t_m) = 0.9945, max(S(tm)-K,0)= 0.0445, PnL(t_m) = 0.0011
# path_id = 963, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.3589, max(S(tm)-K,0)= 0.4089, PnL(t_m) = 0.0005
# path_id = 964, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9534,S(t_m) = 1.3051, max(S(tm)-K,0)= 0.3551, PnL(t_m) = -0.0038
# path_id = 965, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0017,S(t_m) = 0.8359, max(S(tm)-K,0)= -0.1141, PnL(t_m) = -0.0017
# path_id = 966, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9503,S(t_m) = 1.2199, max(S(tm)-K,0)= 0.2699, PnL(t_m) = -0.0007
# path_id = 967, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0049,S(t_m) = 0.8336, max(S(tm)-K,0)= -0.1164, PnL(t_m) = -0.0049
# path_id = 968, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9486,S(t_m) = 1.0010, max(S(tm)-K,0)= 0.0510, PnL(t_m) = 0.0007
# path_id = 969, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9510,S(t_m) = 1.1531, max(S(tm)-K,0)= 0.2031, PnL(t_m) = -0.0015
# path_id = 970, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9431,S(t_m) = 1.1815, max(S(tm)-K,0)= 0.2315, PnL(t_m) = 0.0064
# path_id = 971, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.5781,S(t_m) = 0.9639, max(S(tm)-K,0)= 0.0139, PnL(t_m) = 0.0076
# path_id = 972, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9489,S(t_m) = 1.2214, max(S(tm)-K,0)= 0.2714, PnL(t_m) = 0.0007
# path_id = 973, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.6240,S(t_m) = 0.9699, max(S(tm)-K,0)= 0.0199, PnL(t_m) = 0.0035
# path_id = 974, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9478,S(t_m) = 1.5244, max(S(tm)-K,0)= 0.5744, PnL(t_m) = 0.0017
# path_id = 975, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9478,S(t_m) = 1.3022, max(S(tm)-K,0)= 0.3522, PnL(t_m) = 0.0017
# path_id = 976, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9490,S(t_m) = 1.1857, max(S(tm)-K,0)= 0.2357, PnL(t_m) = 0.0005
# path_id = 977, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0052,S(t_m) = 0.8930, max(S(tm)-K,0)= -0.0570, PnL(t_m) = -0.0052
# path_id = 978, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0017,S(t_m) = 0.7966, max(S(tm)-K,0)= -0.1534, PnL(t_m) = 0.0017
# path_id = 979, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0078,S(t_m) = 0.7936, max(S(tm)-K,0)= -0.1564, PnL(t_m) = 0.0078
# path_id = 980, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9373,S(t_m) = 0.9803, max(S(tm)-K,0)= 0.0303, PnL(t_m) = 0.0024
# path_id = 981, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.1534,S(t_m) = 0.9342, max(S(tm)-K,0)= -0.0158, PnL(t_m) = 0.0021
# path_id = 982, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9506,S(t_m) = 1.2968, max(S(tm)-K,0)= 0.3468, PnL(t_m) = -0.0010
# path_id = 983, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9523,S(t_m) = 1.2576, max(S(tm)-K,0)= 0.3076, PnL(t_m) = -0.0027
# path_id = 984, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.3608, max(S(tm)-K,0)= 0.4108, PnL(t_m) = 0.0014
# path_id = 985, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9471,S(t_m) = 1.3051, max(S(tm)-K,0)= 0.3551, PnL(t_m) = 0.0024
# path_id = 986, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9521,S(t_m) = 1.1918, max(S(tm)-K,0)= 0.2418, PnL(t_m) = -0.0026
# path_id = 987, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9470,S(t_m) = 1.1772, max(S(tm)-K,0)= 0.2272, PnL(t_m) = 0.0025
# path_id = 988, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9502,S(t_m) = 1.0028, max(S(tm)-K,0)= 0.0528, PnL(t_m) = -0.0007
# path_id = 989, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9481,S(t_m) = 1.2686, max(S(tm)-K,0)= 0.3186, PnL(t_m) = 0.0014
# path_id = 990, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0156,S(t_m) = 0.9082, max(S(tm)-K,0)= -0.0418, PnL(t_m) = 0.0072
# path_id = 991, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9505,S(t_m) = 1.3323, max(S(tm)-K,0)= 0.3823, PnL(t_m) = -0.0010
# path_id = 992, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9549,S(t_m) = 1.0233, max(S(tm)-K,0)= 0.0733, PnL(t_m) = -0.0053
# path_id = 993, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9492,S(t_m) = 1.0287, max(S(tm)-K,0)= 0.0787, PnL(t_m) = 0.0003
# path_id = 994, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9482,S(t_m) = 1.0916, max(S(tm)-K,0)= 0.1416, PnL(t_m) = 0.0013
# path_id = 995, PnL(t_0)=-0.6397, PnL(Tm-1) =0.0053,S(t_m) = 0.8821, max(S(tm)-K,0)= -0.0679, PnL(t_m) = 0.0054
# path_id = 996, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9528,S(t_m) = 1.0098, max(S(tm)-K,0)= 0.0598, PnL(t_m) = -0.0033
# path_id = 997, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.9518,S(t_m) = 1.1315, max(S(tm)-K,0)= 0.1815, PnL(t_m) = -0.0023
# path_id = 998, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.7425,S(t_m) = 0.9611, max(S(tm)-K,0)= 0.0111, PnL(t_m) = 0.0082
# path_id = 999, PnL(t_0)=-0.6397, PnL(Tm-1) =-0.0048,S(t_m) = 0.8904, max(S(tm)-K,0)= -0.0596, PnL(t_m) = -0.0048
